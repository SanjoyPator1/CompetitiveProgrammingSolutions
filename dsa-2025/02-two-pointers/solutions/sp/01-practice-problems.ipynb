# %% [markdown]
# # Two Pointers - Practice Problems
#
# This notebook contains practice problems from the Two Pointers section. For each problem, implement your solution in the provided code cell (marked with `TODO`).
#
# - Each problem is followed by a code cell for your solution.
# - Each solution cell is followed by a test cell with sample test cases.
#
# ---

# %% [markdown]
# ## Problem 1: Valid Palindrome
# **Difficulty**: Easy
#
# **Description**: Check if a string is a palindrome, considering only alphanumeric characters and ignoring case.
#
# **Example:**
# - Input: "A man, a plan, a canal: Panama"  Output: True
# - Input: "race a car"  Output: False
#
# **Hint**: Use two pointers from start and end, skip non-alphanumeric characters.

# %%
def is_palindrome(s: str) -> bool:
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 1: Valid Palindrome
assert is_palindrome("A man, a plan, a canal: Panama") == True
assert is_palindrome("race a car") == False
assert is_palindrome("") == True
assert is_palindrome("a.") == True
print("All tests passed for Problem 1.")

# %% [markdown]
# ## Problem 2: Two Sum II - Input Array is Sorted
# **Difficulty**: Easy
#
# **Description**: Find two numbers in a sorted array that add up to a target sum.
#
# **Example:**
# - Input: numbers = [2,7,11,15], target = 9  Output: [1,2] (1-indexed)
#
# **Hint**: Use left and right pointers, move based on sum comparison.

# %%
def two_sum(numbers, target):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 2: Two Sum II
assert two_sum([2,7,11,15], 9) == [1,2]
assert two_sum([2,3,4], 6) == [1,3]
assert two_sum([-1,0], -1) == [1,2]
print("All tests passed for Problem 2.")

# %% [markdown]
# ## Problem 3: Remove Duplicates from Sorted Array
# **Difficulty**: Easy
#
# **Description**: Remove duplicates from a sorted array in-place and return new length.
#
# **Example:**
# - Input: [1,1,2,2,3]  Output: 3 (array becomes [1,2,3,_,_])
#
# **Hint**: Use write pointer to track unique elements position.

# %%
def remove_duplicates(nums):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 3: Remove Duplicates from Sorted Array
nums = [1,1,2,2,3]
k = remove_duplicates(nums)
assert k == 3
assert nums[:k] == [1,2,3]

nums2 = [1,1,1]
k2 = remove_duplicates(nums2)
assert k2 == 1
assert nums2[:k2] == [1]

nums3 = []
k3 = remove_duplicates(nums3)
assert k3 == 0
print("All tests passed for Problem 3.")

# %% [markdown]
# ## Problem 4: Move Zeroes
# **Difficulty**: Easy
#
# **Description**: Move all zeros to the end while maintaining relative order of non-zero elements.
#
# **Example:**
# - Input: [0,1,0,3,12]  Output: [1,3,12,0,0]
#
# **Hint**: Use two pointers - one for reading, one for writing non-zero elements.

# %%
def move_zeroes(nums):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 4: Move Zeroes
nums = [0,1,0,3,12]
move_zeroes(nums)
assert nums == [1,3,12,0,0]

nums2 = [0,0,1]
move_zeroes(nums2)
assert nums2 == [1,0,0]

nums3 = [1,2,3]
move_zeroes(nums3)
assert nums3 == [1,2,3]

print("All tests passed for Problem 4.")

# %% [markdown]
# ## Problem 5: Reverse String
# **Difficulty**: Easy
#
# **Description**: Reverse a string in-place.
#
# **Example:**
# - Input: ['h','e','l','l','o']  Output: ['o','l','l','e','h']
#
# **Hint**: Swap characters from both ends moving inward.

# %%
def reverse_string(s):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 5: Reverse String
s = ['h','e','l','l','o']
reverse_string(s)
assert s == ['o','l','l','e','h']
s2 = ['a']
reverse_string(s2)
assert s2 == ['a']
print("All tests passed for Problem 5.")

# %% [markdown]
# ## Problem 6: Container With Most Water
# **Difficulty**: Medium
#
# **Description**: Find two lines that form a container holding the most water.
#
# **Example:**
# - Input: [1,8,6,2,5,4,8,3,7]  Output: 49
#
# **Hint**: Use two pointers at ends, move the pointer with smaller height.

# %%
def max_area(height):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 6: Container With Most Water
assert max_area([1,8,6,2,5,4,8,3,7]) == 49
assert max_area([1,1]) == 1
print("All tests passed for Problem 6.")

# %% [markdown]
# ## Problem 7: 3Sum
# **Difficulty**: Medium
#
# **Description**: Find all unique triplets that sum to zero.
#
# **Example:**
# - Input: [-1,0,1,2,-1,-4]  Output: [[-1,-1,2],[-1,0,1]]
#
# **Hint**: Sort array, fix one element, use two pointers for remaining two.

# %%
def three_sum(nums):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 7: 3Sum
res = three_sum([-1,0,1,2,-1,-4])
assert sorted([sorted(x) for x in res]) == sorted([[-1,-1,2],[-1,0,1]])
res2 = three_sum([])
assert res2 == []
print("All tests passed for Problem 7.")

# %% [markdown]
# ## Problem 8: Remove Element
# **Difficulty**: Easy
#
# **Description**: Remove all instances of a value in-place and return new length.
#
# **Example:**
# - Input: nums = [3,2,2,3], val = 3  Output: 2 (array becomes [2,2,_,_])
#
# **Hint**: Use write pointer to overwrite elements that aren't equal to val.

# %%
def remove_element(nums, val):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 8: Remove Element
nums = [3,2,2,3]
k = remove_element(nums, 3)
assert k == 2
assert nums[:k] == [2,2]
nums2 = [0,1,2,2,3,0,4,2]
k2 = remove_element(nums2, 2)
assert k2 == 5
print("All tests passed for Problem 8.")

# %% [markdown]
# ## Problem 9: Squares of Sorted Array
# **Difficulty**: Easy
#
# **Description**: Return squares of a sorted array in sorted order.
#
# **Example:**
# - Input: [-4,-1,0,3,10]  Output: [0,1,9,16,100]
#
# **Hint**: Use two pointers from ends since largest squares are at extremes.

# %%
def sorted_squares(nums):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 9: Squares of Sorted Array
assert sorted_squares([-4,-1,0,3,10]) == [0,1,9,16,100]
assert sorted_squares([-7,-3,2,3,11]) == [4,9,9,49,121]
print("All tests passed for Problem 9.")

# %% [markdown]
# ## Problem 10: Trapping Rain Water
# **Difficulty**: Hard
#
# **Description**: Calculate how much water can be trapped after raining.
#
# **Example:**
# - Input: [0,1,0,2,1,0,1,3,2,1,2,1]  Output: 6
#
# **Hint**: Use two pointers with left_max and right_max tracking.

# %%
def trap(height):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 10: Trapping Rain Water
assert trap([0,1,0,2,1,0,1,3,2,1,2,1]) == 6
assert trap([4,2,0,3,2,5]) == 9
print("All tests passed for Problem 10.")

# %% [markdown]
# ## Problem 11: Sort Colors
# **Difficulty**: Medium
#
# **Description**: Sort an array with only 0s, 1s, and 2s in-place.
#
# **Example:**
# - Input: [2,0,2,1,1,0]  Output: [0,0,1,1,2,2]
#
# **Hint**: Use three pointers (Dutch National Flag algorithm).

# %%
def sort_colors(nums):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 11: Sort Colors
nums = [2,0,2,1,1,0]
sort_colors(nums)
assert nums == [0,0,1,1,2,2]
nums2 = [2,0,1]
sort_colors(nums2)
assert nums2 == [0,1,2]
print("All tests passed for Problem 11.")

# %% [markdown]
# ## Problem 12: 4Sum
# **Difficulty**: Medium
#
# **Description**: Find all unique quadruplets that sum to target.
#
# **Example:**
# - Input: nums = [1,0,-1,0,-2,2], target = 0  Output: [[-2,-1,1,2],[-2,0,0,2],[-1,0,0,1]]
#
# **Hint**: Extension of 3Sum with additional outer loop.

# %%
def four_sum(nums, target):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 12: 4Sum
res = four_sum([1,0,-1,0,-2,2], 0)
assert sorted([sorted(x) for x in res]) == sorted([[-2,-1,1,2],[-2,0,0,2],[-1,0,0,1]])
print("All tests passed for Problem 12.")

# %% [markdown]
# ## Problem 13: Partition Labels
# **Difficulty**: Medium
#
# **Description**: Partition string into as many parts as possible so each letter appears in at most one part.
#
# **Example:**
# - Input: "ababcbacadefegdehijhklij"  Output: [9,7,8]
#
# **Hint**: Find last occurrence of each character, use two pointers to track partitions.

# %%
def partition_labels(s):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 13: Partition Labels
assert partition_labels("ababcbacadefegdehijhklij") == [9,7,8]
print("All tests passed for Problem 13.")

# %% [markdown]
# ## Problem 14: Minimum Window Substring
# **Difficulty**: Hard
#
# **Description**: Find minimum window in string s that contains all characters of string t.
#
# **Example:**
# - Input: s = "ADOBECODEBANC", t = "ABC"  Output: "BANC"
#
# **Hint**: Use two pointers to maintain sliding window, expand right until valid, then contract left.

# %%
def min_window(s, t):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 14: Minimum Window Substring
assert min_window("ADOBECODEBANC", "ABC") == "BANC"
print("All tests passed for Problem 14.")

# %% [markdown]
# ## Problem 15: 3Sum Closest
# **Difficulty**: Medium
#
# **Description**: Find three integers whose sum is closest to the target.
#
# **Example:**
# - Input: nums = [-1,2,1,-4], target = 1  Output: 2 (sum of -1 + 2 + 1 = 2)
#
# **Hint**: Similar to 3Sum but track minimum difference instead of exact match.

# %%
def three_sum_closest(nums, target):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 15: 3Sum Closest
assert three_sum_closest([-1,2,1,-4], 1) == 2
print("All tests passed for Problem 15.")

# %% [markdown]
# ## Problem 16: Remove Duplicates from Sorted Array II
# **Difficulty**: Medium
#
# **Description**: Remove duplicates such that each element appears at most twice.
#
# **Example:**
# - Input: [1,1,1,2,2,3]  Output: 5 (array becomes [1,1,2,2,3,_])
#
# **Hint**: Use write pointer and count occurrences of current element.

# %%
def remove_duplicates_ii(nums):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 16: Remove Duplicates from Sorted Array II
nums = [1,1,1,2,2,3]
k = remove_duplicates_ii(nums)
assert k == 5
assert nums[:k] == [1,1,2,2,3]
print("All tests passed for Problem 16.")

# %% [markdown]
# ## Problem 17: Backspace String Compare
# **Difficulty**: Easy
#
# **Description**: Compare two strings where '#' represents backspace operation.
#
# **Example:**
# - Input: s = "ab#c", t = "ad#c"  Output: True (both become "ac")
#
# **Hint**: Process strings from right to left using two pointers.

# %%
def backspace_compare(s, t):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 17: Backspace String Compare
assert backspace_compare("ab#c", "ad#c") == True
assert backspace_compare("ab##", "c#d#") == True
assert backspace_compare("a#c", "b") == False
print("All tests passed for Problem 17.")

# %% [markdown]
# ## Problem 18: Interval List Intersections
# **Difficulty**: Medium
#
# **Description**: Find intersections of two sorted interval lists.
#
# **Example:**
# - Input: firstList = [[0,2],[5,10],[13,23],[24,25]]
#          secondList = [[1,5],[8,12],[15,24],[25,26]]
#   Output: [[1,2],[5,5],[8,10],[15,23],[24,24],[25,25]]
#
# **Hint**: Use two pointers to traverse both lists simultaneously.

# %%
def interval_intersection(firstList, secondList):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 18: Interval List Intersections
first = [[0,2],[5,10],[13,23],[24,25]]
second = [[1,5],[8,12],[15,24],[25,26]]
assert interval_intersection(first, second) == [[1,2],[5,5],[8,10],[15,23],[24,24],[25,25]]
print("All tests passed for Problem 18.")

# %% [markdown]
# ## Problem 19: Sort Array By Parity
# **Difficulty**: Easy
#
# **Description**: Sort array so all even numbers come before odd numbers.
#
# **Example:**
# - Input: [3,1,2,4]  Output: [2,4,3,1] (or any valid arrangement)
#
# **Hint**: Use two pointers - one from start, one from end, swap when needed.

# %%
def sort_array_by_parity(nums):
    # TODO: write your solution here
    pass

# %%
# Tests for Problem 19: Sort Array By Parity
res = sort_array_by_parity([3,1,2,4])
assert set(res[:2]) == {2,4} and set(res[2:]) == {1,3}
print("All tests passed for Problem 19.")

# %% [markdown]
# ## Problem 20: Linked List Cycle II
# **Difficulty**: Medium
#
# **Description**: Find the node where cycle begins in a linked list.
#
# **Example:**
# - Input: head = [3,2,0,-4], pos = 1 (cycle starts at node with value 2)  Output: Node with value 2
#
# **Hint**: Use Floyd's algorithm to detect cycle, then find start position.

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def detect_cycle(head):
    # TODO: write your solution here
    pass
